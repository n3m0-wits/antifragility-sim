# %% [markdown]
# # This is where we are going to be starting:
# `agents.py`: This will house BankAgent and CentralBank classes.
#
# ```model.py```: This will house FinancialModel class (the environment that holds the agents and generates the market shocks).
#
# `run.py`: The execution script that initializes the model, runs it for N steps, and extracts the data.
